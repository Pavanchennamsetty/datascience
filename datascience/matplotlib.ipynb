# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
a=np.array([1,2,3,4,5])
b=np.array([6,7,8,9,10])
plt.plot(a,b)
plt.show()

# %%
a=np.array((1,8))
b=np.array((3,10))
plt.plot(a,b)
plt.show()

# %%
a=np.array([3,1,9,5,4])
plt.plot(a,marker='o')
plt.show()

# %%
plt.plot(a,marker='*')
plt.show()

# %%
plt.plot(a,marker='^')

# %%
a=np.array((3,2,6,9,1))
plt.plot(a,linestyle='dotted')

# %%
plt.plot(a,linestyle='dashed')

# %%
a=np.array((1,2,3,4))
b=np.array((5,6,7,8))
plt.plot(a,b)
plt.title("this is title")
plt.xlabel("this is xlabel")
plt.ylabel("this is ylabel")
# Out:
# Text(0, 0.5, 'this is ylabel')

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
a=np.array((1,2,3,4))
b=np.array((5,6,7,8))
plt.plot(a,b)
plt.title("this is title")
plt.xlabel("this is xlabel")
plt.ylabel("this is ylabel")
plt.grid()

# %%
a=np.array((1,2,3,4))
b=np.array((5,6,7,8))
plt.plot(a,b)
plt.title("this is title")
plt.xlabel("this is xlabel")
plt.ylabel("this is ylabel")
plt.grid(axis='x')

# %%
a=np.array((1,2,3,4))
b=np.array((5,6,7,8))
plt.plot(a,b)
plt.title("this is title")
plt.xlabel("this is xlabel")
plt.ylabel("this is ylabel")
plt.grid(color= 'green',linestyle= '--')

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
a=np.array((1,2,3,4))
b=np.array((5,6,7,8))
plt.subplot(1,2,1)
plt.plot(a,b)
c=np.array((7,2,3,1))
plt.subplots(1,2,2)
plt.plot(a,c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 6
#       4 plt.plot(a,b)
#       5 c=np.array((7,2,3,1))
# ----> 6 plt.subplots(1,2,2)
#       7 plt.plot(a,c)
#
# TypeError: subplots() takes from 0 to 2 positional arguments but 3 were given

# %%
import matplotlib.pyplot as plt
import numpy as np
fig=plt.figure(figsize=(12,8),dpi=500) ###
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 1, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 1, 2)
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
a=np.array((1,2,3))
b=np.array((4,5,6))
plt.subplot(2,3,1)
plt.plot(a,b)
a=np.array((3,2,1))
b=np.array((4,1,7))
plt.subplot(2,3,2)
plt.plot(a,b)
a=np.array((6,9,1))
b=np.array((9,1,8))
plt.subplot(2,3,3)
plt.plot(a,b)
a=np.array((8,6,9))
b=np.array((5,4,7))
plt.subplot(2,3,4)
plt.plot(a,b)
a=np.array((9,0,1))
b=-np.array((0,1,2))
plt.subplot(2,3,5)
plt.plot(a,b)
a=np.array((2,1,5))
b=np.array((4,3,5))
plt.subplot(2,3,6)
plt.plot(a,b)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
a=np.array((1,7,4,9,0,2,1,5))
b=np.array((7,1,9,4,6,2,9,1))
plt.scatter(a,b)
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x,y)
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x,y)

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])
plt.bar(x,y)
# Out:
# <BarContainer object of 4 artists>

# %%
x = ["APPLES", "BANANAS"]
y = [400, 350]
plt.bar(x,y)
# Out:
# <BarContainer object of 2 artists>

# %%
x = np.array(["Apple", "Banana", "Coconut", "Dryfruit"])
y = np.array([3, 8, 1, 10])
plt.barh(x,y)
# Out:
# <BarContainer object of 4 artists>

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, color = "red")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Categories and their values
x = np.array(["Apple", "Banana", "Coconut"])
y = np.array([10, 7, 4])

# Custom colors for each category
colors = ["red", "yellow", "brown"]

# Plotting the bar chart
plt.bar(x, y, color=colors)

# Adding title and labels (optional for clarity)
#plt.title("Fruit Quantities with Custom Colors")
#plt.xlabel("Fruits")
#plt.ylabel("Quantity")

# Show the plot
plt.show()

# %%
import seaborn as sns

# %%
sns.barplot(x=x,y=y,hue=x,palette=["red","yellow","brown"],saturation=0.5)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show()

# %%
a=np.array((90,10,25))
plt.pie(a,explode=[0,0.3,0],shadow=True,labels=["blue","orange","green"])
plt.show()
